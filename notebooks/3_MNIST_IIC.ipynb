# %% [markdown]
# <a href="https://colab.research.google.com/github/ykato27/BERT-Japanese/blob/main/3_MNIST_IIC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # IIC：Invariant Information Clustering for Unsupervised Image Classification and Segmentation
#
# 参考：
# https://github.com/RuABraun/phone-clustering

# %%
# 乱数のシードを固定
import os
import random
import numpy as np
import torch

SEED_VALUE = 1234  # これはなんでも良い
os.environ['PYTHONHASHSEED'] = str(SEED_VALUE)
random.seed(SEED_VALUE)
np.random.seed(SEED_VALUE)
torch.manual_seed(SEED_VALUE)  # PyTorchを使う場合

# %%
# GPUが使えるときにはGPUに（Google Colaboratoryの場合はランタイムからGPUを指定）
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)  

# GPUを使用。cudaと出力されるのを確認する。
# Out:
# cuda

# %%
# MNISTの画像をダウンロードし、DataLoaderにする（TrainとTest）
from torchvision import datasets, transforms

batch_size_train = 512

train_loader = torch.utils.data.DataLoader(
    datasets.MNIST('.', train=True, download=True,
                   transform=transforms.Compose([
                       transforms.ToTensor(),
                   ])),
    batch_size=batch_size_train, shuffle=True, drop_last=True)
# drop_lastは最後のミニバッチが規定のサイズより小さい場合は使用しない設定


test_loader = torch.utils.data.DataLoader(
    datasets.MNIST('.', train=False, transform=transforms.Compose([
        transforms.ToTensor(),
    ])),
    batch_size=1024, shuffle=False)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./MNIST/raw/train-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=0.0, max=9912422.0), HTML(value='')))
# Extracting ./MNIST/raw/train-images-idx3-ubyte.gz to ./MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./MNIST/raw/train-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=0.0, max=28881.0), HTML(value='')))
# Extracting ./MNIST/raw/train-labels-idx1-ubyte.gz to ./MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./MNIST/raw/t10k-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=0.0, max=1648877.0), HTML(value='')))
# Extracting ./MNIST/raw/t10k-images-idx3-ubyte.gz to ./MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./MNIST/raw/t10k-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=0.0, max=4542.0), HTML(value='')))
# Extracting ./MNIST/raw/t10k-labels-idx1-ubyte.gz to ./MNIST/raw
# /usr/local/lib/python3.7/dist-packages/torchvision/datasets/mnist.py:498: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:180.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)

# %%
# ディープラーニングモデル
import torch.nn as nn
import torch.nn.functional as F

OVER_CLUSTRING_Rate = 10  # 多めに分類するoverclsuteringも用意する


class NetIIC(nn.Module):
    def __init__(self):
        super(NetIIC, self).__init__()

        self.conv1 = nn.Conv2d(1, 128, 5, 2, bias=False)
        self.bn1 = nn.BatchNorm2d(128)
        self.conv2 = nn.Conv2d(128, 128, 5, 1, bias=False)
        self.bn2 = nn.BatchNorm2d(128)
        self.conv3 = nn.Conv2d(128, 128, 5, 1, bias=False)
        self.bn3 = nn.BatchNorm2d(128)
        self.conv4 = nn.Conv2d(128, 256, 4, 1, bias=False)
        self.bn4 = nn.BatchNorm2d(256)
        
        # 0-9に対応すると期待したい10種類のクラス
        self.fc = nn.Linear(256, 10)

        # overclustering
        # 実際の想定よりも多めにクラスタリングさせることで、ネットワークで微細な変化を捉えられるようにする
        self.fc_overclustering = nn.Linear(256, 10*OVER_CLUSTRING_Rate)

    def forward(self, x):
        x = F.relu(self.bn1(self.conv1(x)))
        x = F.relu(self.bn2(self.conv2(x)))
        x = F.relu(self.bn3(self.conv3(x)))
        x = F.relu(self.bn4(self.conv4(x)))
        x_prefinal = x.view(x.size(0), -1)
        y = F.softmax(self.fc(x_prefinal), dim=1)

        y_overclustering = F.softmax(self.fc_overclustering(
            x_prefinal), dim=1)  # overclustering

        return y, y_overclustering

# %%
import torch.nn.init as init


def weight_init(m):
    """重み初期化"""
    if isinstance(m, nn.Conv2d):
        init.xavier_normal_(m.weight.data)
        if m.bias is not None:
            init.normal_(m.bias.data)
    elif isinstance(m, nn.BatchNorm2d):
        init.normal_(m.weight.data, mean=1, std=0.02)
        init.constant_(m.bias.data, 0)
    elif isinstance(m, nn.Linear):
        # Xavier
        #init.xavier_normal_(m.weight.data)

        # He 
        init.kaiming_normal_(m.weight.data)
        
        if m.bias is not None:
            init.normal_(m.bias.data)

# %%
# データにノイズを加える関数の定義
import torchvision as tv
import torchvision.transforms.functional as TF


def perturb_imagedata(x):
    y = x.clone()
    batch_size = x.size(0)

    # ランダムなアフィン変換を実施
    trans = tv.transforms.RandomAffine(15, (0.2, 0.2,), (0.2, 0.75,))
    for i in range(batch_size):
        y[i, 0] = TF.to_tensor(trans(TF.to_pil_image(y[i, 0])))

    # ノイズを加える
    noise = torch.randn(batch_size, 1, x.size(2), x.size(3))
    div = torch.randint(20, 30, (batch_size,),
                        dtype=torch.float32).view(batch_size, 1, 1, 1)
    y += noise / div

    return y

# %%
# IISによる損失関数の定義
# 参考：https://github.com/RuABraun/phone-clustering/blob/master/mnist_basic.py
import sys


def compute_joint(x_out, x_tf_out):

    # x_out、x_tf_outは torch.Size([512, 10])。この二つをかけ算して同時分布を求める、torch.Size([2048, 10, 10])にする。
    # torch.Size([512, 10, 1]) * torch.Size([512, 1, 10])
    p_i_j = x_out.unsqueeze(2) * x_tf_out.unsqueeze(1)
    # p_i_j は　torch.Size([512, 10, 10])

    # 全ミニバッチを足し算する ⇒ torch.Size([10, 10])
    p_i_j = p_i_j.sum(dim=0)

    # 転置行列と足し算して割り算（対称化） ⇒ torch.Size([10, 10])
    p_i_j = (p_i_j + p_i_j.t()) / 2.

    # 規格化 ⇒ torch.Size([10, 10])
    p_i_j = p_i_j / p_i_j.sum()

    return p_i_j
    # 結局、p_i_jは通常画像の判定出力10種類と、変換画像の判定10種類の100パターンに対して、全ミニバッチが100パターンのどれだったのかの確率分布表を示す


def IID_loss(x_out, x_tf_out, EPS=sys.float_info.epsilon):
    # torch.Size([512, 10])、後ろの10は分類数なので、overclusteringのときは100
    bs, k = x_out.size()
    p_i_j = compute_joint(x_out, x_tf_out)  # torch.Size([10, 10])

    # 同時確率の分布表から、変換画像の10パターンをsumをして周辺化し、元画像だけの周辺確率の分布表を作る
    p_i = p_i_j.sum(dim=1).view(k, 1).expand(k, k)
    # 同時確率の分布表から、元画像の10パターンをsumをして周辺化し、変換画像だけの周辺確率の分布表を作る
    p_j = p_i_j.sum(dim=0).view(1, k).expand(k, k)

    # 0に近い値をlogに入れると発散するので、避ける
    #p_i_j[(p_i_j < EPS).data] = EPS
    #p_j[(p_j < EPS).data] = EPS
    #p_i[(p_i < EPS).data] = EPS
    # 参考GitHubの実装（↑）は、PyTorchのバージョン1.3以上だとエラーになる
    # https://discuss.pytorch.org/t/pytorch-1-3-showing-an-error-perhaps-for-loss-computed-from-paired-outputs/68790/3

    # 0に近い値をlogに入れると発散するので、避ける
    p_i_j = torch.where(p_i_j < EPS, torch.tensor(
        [EPS], device=p_i_j.device), p_i_j)
    p_j = torch.where(p_j < EPS, torch.tensor([EPS], device=p_j.device), p_j)
    p_i = torch.where(p_i < EPS, torch.tensor([EPS], device=p_i.device), p_i)

    # 元画像、変換画像の同時確率と周辺確率から、相互情報量を計算
    # ただし、マイナスをかけて最小化問題にする
    """
    相互情報量を最大化したい
    ⇒結局、x_out, x_tf_outが持ちあう情報量が多くなって欲しい
    ⇒要は、x_out, x_tf_outが一緒になって欲しい

    p_i_jはx_out, x_tf_outの同時確率分布で、ミニバッチが極力、10×10のいろんなパターン、満遍なく一様が嬉しい
    
    前半の項、torch.log(p_i_j)はp_ijがどれも1に近いと大きな値（0に近い）になる。
    どれかが1であと0でバラついていないと、log0で小さな値（負の大きな値）になる
    つまり前半の項は、

    後半の項は、元画像、もしくは変換画像について、それぞれ周辺化して10通りのどれになるかを計算した項。
    周辺化した10×10のパターンを引き算して、前半の項が小さくなるのであれば、
    x_outとx_tf_outはあまり情報を共有していなかったことになる。
    """
    # https://qiita.com/Amanokawa/items/0aa24bc396dd88fb7d2a
    # を参考に、重みalphaを追加
    # 同時確率分布表のばらつきによる罰則を小さく ＝ 同時確率の分布がバラつきやすくする
    alpha = 2.0  # 論文や通常の相互情報量の計算はalphaは1です

    loss = -1*(p_i_j * (torch.log(p_i_j) - alpha *
                        torch.log(p_j) - alpha*torch.log(p_i))).sum()

    return loss

# %%
# 訓練の実施
total_epoch = 20


# モデル
model = NetIIC()
model.apply(weight_init)
model.to(device)

# 最適化関数を設定
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)


def train(total_epoch, model, train_loader, optimizer, device):

    model.train()
    scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(
        optimizer, T_0=2, T_mult=2)

    for epoch in range(total_epoch):
        for batch_idx, (data, target) in enumerate(train_loader):

            # 学習率変化
            scheduler.step()

            # 微妙に変換したデータを作る。SIMULTANEOUS_NUM分のペアを作る
            data_perturb = perturb_imagedata(data)  # ノイズを与える

            # GPUに送れる場合は送る
            data = data.to(device)
            data_perturb = data_perturb.to(device)

            # 最適化関数の初期化
            optimizer.zero_grad()

            # ニューラルネットワーク出力
            output, output_overclustering = model(data)
            output_perturb, output_perturb_overclustering = model(data_perturb)

            # 損失の計算
            loss1 = IID_loss(output, output_perturb)
            loss2 = IID_loss(output_overclustering,
                             output_perturb_overclustering)
            loss = loss1 + loss2

            # 損失を減らすように更新
            loss.backward()
            optimizer.step()

            # ログ出力
            if batch_idx % 10 == 0:
                print('Train Epoch {}:iter{} - \tLoss1: {:.6f}- \tLoss2: {:.6f}- \tLoss_total: {:.6f}'.format(
                    epoch, batch_idx, loss1.item(), loss2.item(), loss1.item()+loss2.item()))

    return model, optimizer


model_trained, optimizer = train(
    total_epoch, model, train_loader, optimizer, device)
# Out:
# Train Epoch 0:iter0 - 	Loss1: -4.060220- 	Loss2: -7.888132- 	Loss_total: -11.948352
# Train Epoch 0:iter10 - 	Loss1: -4.611292- 	Loss2: -9.003188- 	Loss_total: -13.614480
# Train Epoch 0:iter20 - 	Loss1: -4.611467- 	Loss2: -9.183082- 	Loss_total: -13.794549
# Train Epoch 0:iter30 - 	Loss1: -4.632646- 	Loss2: -9.220558- 	Loss_total: -13.853204
# Train Epoch 0:iter40 - 	Loss1: -4.661359- 	Loss2: -9.243674- 	Loss_total: -13.905033
# Train Epoch 0:iter50 - 	Loss1: -4.683805- 	Loss2: -9.262733- 	Loss_total: -13.946538
# Train Epoch 0:iter60 - 	Loss1: -4.678495- 	Loss2: -9.263959- 	Loss_total: -13.942454
# Train Epoch 0:iter70 - 	Loss1: -4.761348- 	Loss2: -9.282362- 	Loss_total: -14.043710
# Train Epoch 0:iter80 - 	Loss1: -4.865394- 	Loss2: -9.360165- 	Loss_total: -14.225558
# Train Epoch 0:iter90 - 	Loss1: -4.960638- 	Loss2: -9.419643- 	Loss_total: -14.380281
# Train Epoch 0:iter100 - 	Loss1: -5.009453- 	Loss2: -9.466017- 	Loss_total: -14.475470
# Train Epoch 0:iter110 - 	Loss1: -5.057301- 	Loss2: -9.505531- 	Loss_total: -14.562832
# Train Epoch 1:iter0 - 	Loss1: -5.078665- 	Loss2: -9.508389- 	Loss_total: -14.587053
# Train Epoch 1:iter10 - 	Loss1: -4.988012- 	Loss2: -9.466325- 	Loss_total: -14.454337
# Train Epoch 1:iter20 - 	Loss1: -5.080325- 	Loss2: -9.600590- 	Loss_total: -14.680915
# Train Epoch 1:iter30 - 	Loss1: -5.168097- 	Loss2: -9.744434- 	Loss_total: -14.912532
# Train Epoch 1:iter40 - 	Loss1: -5.181648- 	Loss2: -9.855542- 	Loss_total: -15.037190
# Train Epoch 1:iter50 - 	Loss1: -5.293850- 	Loss2: -10.013722- 	Loss_total: -15.307572
# Train Epoch 1:iter60 - 	Loss1: -5.318013- 	Loss2: -10.112649- 	Loss_total: -15.430662
# Train Epoch 1:iter70 - 	Loss1: -5.334870- 	Loss2: -10.238857- 	Loss_total: -15.573728
# Train Epoch 1:iter80 - 	Loss1: -5.342963- 	Loss2: -10.263691- 	Loss_total: -15.606654
# Train Epoch 1:iter90 - 	Loss1: -5.443414- 	Loss2: -10.371538- 	Loss_total: -15.814952
# Train Epoch 1:iter100 - 	Loss1: -5.441551- 	Loss2: -10.414930- 	Loss_total: -15.856482
# Train Epoch 1:iter110 - 	Loss1: -5.466033- 	Loss2: -10.487525- 	Loss_total: -15.953558
# Train Epoch 2:iter0 - 	Loss1: -5.403698- 	Loss2: -10.406637- 	Loss_total: -15.810336
# Train Epoch 2:iter10 - 	Loss1: -5.431201- 	Loss2: -10.474651- 	Loss_total: -15.905852
# Train Epoch 2:iter20 - 	Loss1: -5.349896- 	Loss2: -10.386035- 	Loss_total: -15.735931
# Train Epoch 2:iter30 - 	Loss1: -5.486618- 	Loss2: -10.505413- 	Loss_total: -15.992031
# Train Epoch 2:iter40 - 	Loss1: -5.555694- 	Loss2: -10.722584- 	Loss_total: -16.278278
# Train Epoch 2:iter50 - 	Loss1: -5.549855- 	Loss2: -10.856510- 	Loss_total: -16.406365
# Train Epoch 2:iter60 - 	Loss1: -5.691168- 	Loss2: -11.015108- 	Loss_total: -16.706276
# Train Epoch 2:iter70 - 	Loss1: -5.683498- 	Loss2: -11.120459- 	Loss_total: -16.803957
# Train Epoch 2:iter80 - 	Loss1: -5.671360- 	Loss2: -11.221218- 	Loss_total: -16.892579
# Train Epoch 2:iter90 - 	Loss1: -5.756438- 	Loss2: -11.269808- 	Loss_total: -17.026246
# Train Epoch 2:iter100 - 	Loss1: -5.742996- 	Loss2: -11.300947- 	Loss_total: -17.043943
# Train Epoch 2:iter110 - 	Loss1: -5.776135- 	Loss2: -11.400900- 	Loss_total: -17.177035
# Train Epoch 3:iter0 - 	Loss1: -5.709513- 	Loss2: -11.336113- 	Loss_total: -17.045626
# Train Epoch 3:iter10 - 	Loss1: -5.818069- 	Loss2: -11.449528- 	Loss_total: -17.267596
# Train Epoch 3:iter20 - 	Loss1: -5.797407- 	Loss2: -11.402871- 	Loss_total: -17.200278
# Train Epoch 3:iter30 - 	Loss1: -5.887704- 	Loss2: -11.492065- 	Loss_total: -17.379769
# Train Epoch 3:iter40 - 	Loss1: -5.830174- 	Loss2: -11.480902- 	Loss_total: -17.311076
# Train Epoch 3:iter50 - 	Loss1: -5.863814- 	Loss2: -11.509472- 	Loss_total: -17.373286
# Train Epoch 3:iter60 - 	Loss1: -5.919400- 	Loss2: -11.569252- 	Loss_total: -17.488652
# Train Epoch 3:iter70 - 	Loss1: -5.949003- 	Loss2: -11.545938- 	Loss_total: -17.494940
# Train Epoch 3:iter80 - 	Loss1: -6.004858- 	Loss2: -11.652042- 	Loss_total: -17.656901
# Train Epoch 3:iter90 - 	Loss1: -5.890149- 	Loss2: -11.605400- 	Loss_total: -17.495549
# Train Epoch 3:iter100 - 	Loss1: -5.889619- 	Loss2: -11.580282- 	Loss_total: -17.469901
# Train Epoch 3:iter110 - 	Loss1: -5.937756- 	Loss2: -11.582610- 	Loss_total: -17.520366
# Train Epoch 4:iter0 - 	Loss1: -5.991243- 	Loss2: -11.650745- 	Loss_total: -17.641988
# Train Epoch 4:iter10 - 	Loss1: -5.956767- 	Loss2: -11.670416- 	Loss_total: -17.627183
# Train Epoch 4:iter20 - 	Loss1: -5.936190- 	Loss2: -11.612174- 	Loss_total: -17.548364
# Train Epoch 4:iter30 - 	Loss1: -5.900745- 	Loss2: -11.612167- 	Loss_total: -17.512913
# Train Epoch 4:iter40 - 	Loss1: -6.067002- 	Loss2: -11.690381- 	Loss_total: -17.757383
# Train Epoch 4:iter50 - 	Loss1: -5.808357- 	Loss2: -11.558524- 	Loss_total: -17.366881
# Train Epoch 4:iter60 - 	Loss1: -5.798641- 	Loss2: -11.540726- 	Loss_total: -17.339367
# Train Epoch 4:iter70 - 	Loss1: -5.870835- 	Loss2: -11.572752- 	Loss_total: -17.443587
# Train Epoch 4:iter80 - 	Loss1: -5.851989- 	Loss2: -11.572952- 	Loss_total: -17.424942
# Train Epoch 4:iter90 - 	Loss1: -5.860125- 	Loss2: -11.586666- 	Loss_total: -17.446791
# Train Epoch 4:iter100 - 	Loss1: -5.935373- 	Loss2: -11.663794- 	Loss_total: -17.599167
# Train Epoch 4:iter110 - 	Loss1: -5.865600- 	Loss2: -11.648110- 	Loss_total: -17.513710
# Train Epoch 5:iter0 - 	Loss1: -5.809254- 	Loss2: -11.635465- 	Loss_total: -17.444719
# Train Epoch 5:iter10 - 	Loss1: -5.949153- 	Loss2: -11.674707- 	Loss_total: -17.623860
# Train Epoch 5:iter20 - 	Loss1: -5.947246- 	Loss2: -11.710457- 	Loss_total: -17.657702
# Train Epoch 5:iter30 - 	Loss1: -5.975659- 	Loss2: -11.702812- 	Loss_total: -17.678472
# Train Epoch 5:iter40 - 	Loss1: -5.939276- 	Loss2: -11.693422- 	Loss_total: -17.632698
# Train Epoch 5:iter50 - 	Loss1: -5.931988- 	Loss2: -11.734095- 	Loss_total: -17.666082
# Train Epoch 5:iter60 - 	Loss1: -6.021602- 	Loss2: -11.756969- 	Loss_total: -17.778572
# Train Epoch 5:iter70 - 	Loss1: -5.928811- 	Loss2: -11.772852- 	Loss_total: -17.701663
# Train Epoch 5:iter80 - 	Loss1: -5.920030- 	Loss2: -11.761056- 	Loss_total: -17.681086
# Train Epoch 5:iter90 - 	Loss1: -6.028146- 	Loss2: -11.815660- 	Loss_total: -17.843806
# Train Epoch 5:iter100 - 	Loss1: -5.970572- 	Loss2: -11.760359- 	Loss_total: -17.730931
# Train Epoch 5:iter110 - 	Loss1: -6.039902- 	Loss2: -11.841377- 	Loss_total: -17.881279
# Train Epoch 6:iter0 - 	Loss1: -6.041426- 	Loss2: -11.868406- 	Loss_total: -17.909832
# Train Epoch 6:iter10 - 	Loss1: -6.065381- 	Loss2: -11.866635- 	Loss_total: -17.932016
# Train Epoch 6:iter20 - 	Loss1: -6.102730- 	Loss2: -11.878145- 	Loss_total: -17.980875
# Train Epoch 6:iter30 - 	Loss1: -5.930106- 	Loss2: -11.805934- 	Loss_total: -17.736040
# Train Epoch 6:iter40 - 	Loss1: -6.096852- 	Loss2: -11.869654- 	Loss_total: -17.966506
# Train Epoch 6:iter50 - 	Loss1: -6.038321- 	Loss2: -11.897723- 	Loss_total: -17.936044
# Train Epoch 6:iter60 - 	Loss1: -6.104107- 	Loss2: -11.863194- 	Loss_total: -17.967300
# Train Epoch 6:iter70 - 	Loss1: -6.068077- 	Loss2: -11.916211- 	Loss_total: -17.984288
# Train Epoch 6:iter80 - 	Loss1: -6.134114- 	Loss2: -11.900346- 	Loss_total: -18.034460
# Train Epoch 6:iter90 - 	Loss1: -6.104365- 	Loss2: -11.897902- 	Loss_total: -18.002267
# Train Epoch 6:iter100 - 	Loss1: -6.148559- 	Loss2: -11.964228- 	Loss_total: -18.112787
# Train Epoch 6:iter110 - 	Loss1: -6.042516- 	Loss2: -11.914865- 	Loss_total: -17.957381
# Train Epoch 7:iter0 - 	Loss1: -6.137508- 	Loss2: -11.927616- 	Loss_total: -18.065125
# Train Epoch 7:iter10 - 	Loss1: -6.147899- 	Loss2: -11.931931- 	Loss_total: -18.079831
# Train Epoch 7:iter20 - 	Loss1: -6.164455- 	Loss2: -11.919077- 	Loss_total: -18.083532
# Train Epoch 7:iter30 - 	Loss1: -6.087983- 	Loss2: -11.935980- 	Loss_total: -18.023963
# Train Epoch 7:iter40 - 	Loss1: -6.127253- 	Loss2: -11.901665- 	Loss_total: -18.028917
# Train Epoch 7:iter50 - 	Loss1: -6.218184- 	Loss2: -11.958876- 	Loss_total: -18.177060
# Train Epoch 7:iter60 - 	Loss1: -6.093967- 	Loss2: -11.939193- 	Loss_total: -18.033160
# Train Epoch 7:iter70 - 	Loss1: -6.153821- 	Loss2: -11.962757- 	Loss_total: -18.116578
# Train Epoch 7:iter80 - 	Loss1: -6.124557- 	Loss2: -11.993057- 	Loss_total: -18.117615
# Train Epoch 7:iter90 - 	Loss1: -6.190185- 	Loss2: -11.984846- 	Loss_total: -18.175031
# Train Epoch 7:iter100 - 	Loss1: -6.115534- 	Loss2: -11.948700- 	Loss_total: -18.064234
# Train Epoch 7:iter110 - 	Loss1: -6.066108- 	Loss2: -11.972368- 	Loss_total: -18.038476
# Train Epoch 8:iter0 - 	Loss1: -6.258361- 	Loss2: -12.029182- 	Loss_total: -18.287543
# Train Epoch 8:iter10 - 	Loss1: -6.168372- 	Loss2: -11.993715- 	Loss_total: -18.162087
# Train Epoch 8:iter20 - 	Loss1: -6.187535- 	Loss2: -12.016155- 	Loss_total: -18.203690
# Train Epoch 8:iter30 - 	Loss1: -6.215626- 	Loss2: -12.007199- 	Loss_total: -18.222826
# Train Epoch 8:iter40 - 	Loss1: -6.236101- 	Loss2: -12.079971- 	Loss_total: -18.316072
# Train Epoch 8:iter50 - 	Loss1: -6.094762- 	Loss2: -11.979506- 	Loss_total: -18.074268
# Train Epoch 8:iter60 - 	Loss1: -6.193362- 	Loss2: -12.013626- 	Loss_total: -18.206988
# Train Epoch 8:iter70 - 	Loss1: -6.149124- 	Loss2: -12.003230- 	Loss_total: -18.152354
# Train Epoch 8:iter80 - 	Loss1: -6.229519- 	Loss2: -12.027204- 	Loss_total: -18.256722
# Train Epoch 8:iter90 - 	Loss1: -6.070207- 	Loss2: -11.938317- 	Loss_total: -18.008524
# Train Epoch 8:iter100 - 	Loss1: -6.082348- 	Loss2: -11.910183- 	Loss_total: -17.992531
# Train Epoch 8:iter110 - 	Loss1: -6.080398- 	Loss2: -11.911099- 	Loss_total: -17.991497
# Train Epoch 9:iter0 - 	Loss1: -6.130266- 	Loss2: -11.932613- 	Loss_total: -18.062879
# Train Epoch 9:iter10 - 	Loss1: -6.190228- 	Loss2: -11.921734- 	Loss_total: -18.111962
# Train Epoch 9:iter20 - 	Loss1: -6.093894- 	Loss2: -11.882666- 	Loss_total: -17.976560
# Train Epoch 9:iter30 - 	Loss1: -6.136742- 	Loss2: -11.909475- 	Loss_total: -18.046217
# Train Epoch 9:iter40 - 	Loss1: -6.067197- 	Loss2: -11.881810- 	Loss_total: -17.949007
# Train Epoch 9:iter50 - 	Loss1: -6.086351- 	Loss2: -12.006243- 	Loss_total: -18.092594
# Train Epoch 9:iter60 - 	Loss1: -6.193753- 	Loss2: -11.998446- 	Loss_total: -18.192198
# Train Epoch 9:iter70 - 	Loss1: -6.124601- 	Loss2: -11.978324- 	Loss_total: -18.102925
# Train Epoch 9:iter80 - 	Loss1: -6.082544- 	Loss2: -11.936665- 	Loss_total: -18.019209
# Train Epoch 9:iter90 - 	Loss1: -6.131102- 	Loss2: -12.070150- 	Loss_total: -18.201252
# Train Epoch 9:iter100 - 	Loss1: -6.150391- 	Loss2: -11.973581- 	Loss_total: -18.123972
# Train Epoch 9:iter110 - 	Loss1: -6.135997- 	Loss2: -12.021204- 	Loss_total: -18.157201
# Train Epoch 10:iter0 - 	Loss1: -6.062976- 	Loss2: -11.997622- 	Loss_total: -18.060598
# Train Epoch 10:iter10 - 	Loss1: -6.295789- 	Loss2: -12.117174- 	Loss_total: -18.412963
# Train Epoch 10:iter20 - 	Loss1: -6.215755- 	Loss2: -12.021643- 	Loss_total: -18.237397
# Train Epoch 10:iter30 - 	Loss1: -6.186854- 	Loss2: -12.048141- 	Loss_total: -18.234995
# Train Epoch 10:iter40 - 	Loss1: -6.196122- 	Loss2: -12.050680- 	Loss_total: -18.246802
# Train Epoch 10:iter50 - 	Loss1: -6.249171- 	Loss2: -12.102195- 	Loss_total: -18.351366
# Train Epoch 10:iter60 - 	Loss1: -6.266283- 	Loss2: -12.088543- 	Loss_total: -18.354826
# Train Epoch 10:iter70 - 	Loss1: -6.180442- 	Loss2: -12.021923- 	Loss_total: -18.202365
# Train Epoch 10:iter80 - 	Loss1: -6.177025- 	Loss2: -12.061420- 	Loss_total: -18.238445
# Train Epoch 10:iter90 - 	Loss1: -6.197609- 	Loss2: -12.106373- 	Loss_total: -18.303982
# Train Epoch 10:iter100 - 	Loss1: -6.147257- 	Loss2: -12.069538- 	Loss_total: -18.216795
# Train Epoch 10:iter110 - 	Loss1: -6.221524- 	Loss2: -12.046354- 	Loss_total: -18.267879
# Train Epoch 11:iter0 - 	Loss1: -6.100591- 	Loss2: -12.004694- 	Loss_total: -18.105285
# Train Epoch 11:iter10 - 	Loss1: -6.298771- 	Loss2: -12.102446- 	Loss_total: -18.401217
# Train Epoch 11:iter20 - 	Loss1: -6.068560- 	Loss2: -12.019449- 	Loss_total: -18.088009
# Train Epoch 11:iter30 - 	Loss1: -6.189665- 	Loss2: -12.101091- 	Loss_total: -18.290756
# Train Epoch 11:iter40 - 	Loss1: -6.182762- 	Loss2: -12.088315- 	Loss_total: -18.271077
# Train Epoch 11:iter50 - 	Loss1: -6.210567- 	Loss2: -12.044319- 	Loss_total: -18.254886
# Train Epoch 11:iter60 - 	Loss1: -6.257077- 	Loss2: -12.080381- 	Loss_total: -18.337458
# Train Epoch 11:iter70 - 	Loss1: -6.213925- 	Loss2: -12.101639- 	Loss_total: -18.315564
# Train Epoch 11:iter80 - 	Loss1: -6.209737- 	Loss2: -12.122320- 	Loss_total: -18.332057
# Train Epoch 11:iter90 - 	Loss1: -6.326679- 	Loss2: -12.127072- 	Loss_total: -18.453752
# Train Epoch 11:iter100 - 	Loss1: -6.225374- 	Loss2: -12.128412- 	Loss_total: -18.353786
# Train Epoch 11:iter110 - 	Loss1: -6.266423- 	Loss2: -12.137896- 	Loss_total: -18.404318
# Train Epoch 12:iter0 - 	Loss1: -6.307388- 	Loss2: -12.149591- 	Loss_total: -18.456980
# Train Epoch 12:iter10 - 	Loss1: -6.282903- 	Loss2: -12.148693- 	Loss_total: -18.431596
# Train Epoch 12:iter20 - 	Loss1: -6.237531- 	Loss2: -12.188722- 	Loss_total: -18.426252
# Train Epoch 12:iter30 - 	Loss1: -6.344101- 	Loss2: -12.165178- 	Loss_total: -18.509279
# Train Epoch 12:iter40 - 	Loss1: -6.318918- 	Loss2: -12.177574- 	Loss_total: -18.496492
# Train Epoch 12:iter50 - 	Loss1: -6.307510- 	Loss2: -12.219259- 	Loss_total: -18.526770
# Train Epoch 12:iter60 - 	Loss1: -6.256101- 	Loss2: -12.175537- 	Loss_total: -18.431638
# Train Epoch 12:iter70 - 	Loss1: -6.207810- 	Loss2: -12.175699- 	Loss_total: -18.383510
# Train Epoch 12:iter80 - 	Loss1: -6.298185- 	Loss2: -12.147650- 	Loss_total: -18.445835
# Train Epoch 12:iter90 - 	Loss1: -6.299184- 	Loss2: -12.209774- 	Loss_total: -18.508958
# Train Epoch 12:iter100 - 	Loss1: -6.204083- 	Loss2: -12.144716- 	Loss_total: -18.348799
# Train Epoch 12:iter110 - 	Loss1: -6.256714- 	Loss2: -12.134601- 	Loss_total: -18.391315
# Train Epoch 13:iter0 - 	Loss1: -6.319348- 	Loss2: -12.166365- 	Loss_total: -18.485713
# Train Epoch 13:iter10 - 	Loss1: -6.280208- 	Loss2: -12.172007- 	Loss_total: -18.452215
# Train Epoch 13:iter20 - 	Loss1: -6.367432- 	Loss2: -12.239655- 	Loss_total: -18.607086
# Train Epoch 13:iter30 - 	Loss1: -6.251902- 	Loss2: -12.217813- 	Loss_total: -18.469715
# Train Epoch 13:iter40 - 	Loss1: -6.412702- 	Loss2: -12.250854- 	Loss_total: -18.663556
# Train Epoch 13:iter50 - 	Loss1: -6.339197- 	Loss2: -12.223631- 	Loss_total: -18.562828
# Train Epoch 13:iter60 - 	Loss1: -6.362877- 	Loss2: -12.227421- 	Loss_total: -18.590298
# Train Epoch 13:iter70 - 	Loss1: -6.341470- 	Loss2: -12.171467- 	Loss_total: -18.512937
# Train Epoch 13:iter80 - 	Loss1: -6.292691- 	Loss2: -12.281252- 	Loss_total: -18.573943
# Train Epoch 13:iter90 - 	Loss1: -6.363288- 	Loss2: -12.286489- 	Loss_total: -18.649776
# Train Epoch 13:iter100 - 	Loss1: -6.351904- 	Loss2: -12.176936- 	Loss_total: -18.528840
# Train Epoch 13:iter110 - 	Loss1: -6.352354- 	Loss2: -12.254922- 	Loss_total: -18.607275
# Train Epoch 14:iter0 - 	Loss1: -6.235384- 	Loss2: -12.199553- 	Loss_total: -18.434937
# Train Epoch 14:iter10 - 	Loss1: -6.388951- 	Loss2: -12.241881- 	Loss_total: -18.630833
# Train Epoch 14:iter20 - 	Loss1: -6.428586- 	Loss2: -12.293479- 	Loss_total: -18.722065
# Train Epoch 14:iter30 - 	Loss1: -6.231458- 	Loss2: -12.166193- 	Loss_total: -18.397651
# Train Epoch 14:iter40 - 	Loss1: -6.401109- 	Loss2: -12.227822- 	Loss_total: -18.628931
# Train Epoch 14:iter50 - 	Loss1: -6.375162- 	Loss2: -12.217341- 	Loss_total: -18.592504
# Train Epoch 14:iter60 - 	Loss1: -6.305208- 	Loss2: -12.210806- 	Loss_total: -18.516014
# Train Epoch 14:iter70 - 	Loss1: -6.204807- 	Loss2: -12.164753- 	Loss_total: -18.369560
# Train Epoch 14:iter80 - 	Loss1: -6.397275- 	Loss2: -12.238293- 	Loss_total: -18.635568
# Train Epoch 14:iter90 - 	Loss1: -6.388957- 	Loss2: -12.250717- 	Loss_total: -18.639674
# Train Epoch 14:iter100 - 	Loss1: -6.468092- 	Loss2: -12.254080- 	Loss_total: -18.722172
# Train Epoch 14:iter110 - 	Loss1: -6.295335- 	Loss2: -12.263966- 	Loss_total: -18.559300
# Train Epoch 15:iter0 - 	Loss1: -6.371727- 	Loss2: -12.253120- 	Loss_total: -18.624847
# Train Epoch 15:iter10 - 	Loss1: -6.370405- 	Loss2: -12.322498- 	Loss_total: -18.692904
# Train Epoch 15:iter20 - 	Loss1: -6.401648- 	Loss2: -12.273626- 	Loss_total: -18.675274
# Train Epoch 15:iter30 - 	Loss1: -6.356450- 	Loss2: -12.302208- 	Loss_total: -18.658658
# Train Epoch 15:iter40 - 	Loss1: -6.382299- 	Loss2: -12.325544- 	Loss_total: -18.707844
# Train Epoch 15:iter50 - 	Loss1: -6.389991- 	Loss2: -12.267128- 	Loss_total: -18.657119
# Train Epoch 15:iter60 - 	Loss1: -6.300162- 	Loss2: -12.232191- 	Loss_total: -18.532353
# Train Epoch 15:iter70 - 	Loss1: -6.371129- 	Loss2: -12.305152- 	Loss_total: -18.676281
# Train Epoch 15:iter80 - 	Loss1: -6.360674- 	Loss2: -12.272968- 	Loss_total: -18.633643
# Train Epoch 15:iter90 - 	Loss1: -6.324568- 	Loss2: -12.222063- 	Loss_total: -18.546631
# Train Epoch 15:iter100 - 	Loss1: -6.370785- 	Loss2: -12.227633- 	Loss_total: -18.598417
# Train Epoch 15:iter110 - 	Loss1: -6.383850- 	Loss2: -12.262570- 	Loss_total: -18.646420
# Train Epoch 16:iter0 - 	Loss1: -6.353237- 	Loss2: -12.253889- 	Loss_total: -18.607126
# Train Epoch 16:iter10 - 	Loss1: -6.265786- 	Loss2: -12.181981- 	Loss_total: -18.447767
# Train Epoch 16:iter20 - 	Loss1: -6.335771- 	Loss2: -12.270323- 	Loss_total: -18.606093
# Train Epoch 16:iter30 - 	Loss1: -6.360756- 	Loss2: -12.274444- 	Loss_total: -18.635200
# Train Epoch 16:iter40 - 	Loss1: -6.367617- 	Loss2: -12.298990- 	Loss_total: -18.666607
# Train Epoch 16:iter50 - 	Loss1: -6.281866- 	Loss2: -12.281849- 	Loss_total: -18.563715
# Train Epoch 16:iter60 - 	Loss1: -6.379573- 	Loss2: -12.337650- 	Loss_total: -18.717223
# Train Epoch 16:iter70 - 	Loss1: -6.474895- 	Loss2: -12.337746- 	Loss_total: -18.812640
# Train Epoch 16:iter80 - 	Loss1: -6.404047- 	Loss2: -12.273046- 	Loss_total: -18.677093
# Train Epoch 16:iter90 - 	Loss1: -6.473917- 	Loss2: -12.341274- 	Loss_total: -18.815191
# Train Epoch 16:iter100 - 	Loss1: -6.433256- 	Loss2: -12.306604- 	Loss_total: -18.739860
# Train Epoch 16:iter110 - 	Loss1: -6.394162- 	Loss2: -12.263482- 	Loss_total: -18.657644
# Train Epoch 17:iter0 - 	Loss1: -6.462210- 	Loss2: -12.315271- 	Loss_total: -18.777481
# Train Epoch 17:iter10 - 	Loss1: -6.349364- 	Loss2: -12.233582- 	Loss_total: -18.582946
# Train Epoch 17:iter20 - 	Loss1: -6.319858- 	Loss2: -12.295242- 	Loss_total: -18.615100
# Train Epoch 17:iter30 - 	Loss1: -6.415564- 	Loss2: -12.326500- 	Loss_total: -18.742064
# Train Epoch 17:iter40 - 	Loss1: -6.292253- 	Loss2: -12.272081- 	Loss_total: -18.564334
# Train Epoch 17:iter50 - 	Loss1: -6.378530- 	Loss2: -12.319160- 	Loss_total: -18.697690
# Train Epoch 17:iter60 - 	Loss1: -6.294943- 	Loss2: -12.202002- 	Loss_total: -18.496945
# Train Epoch 17:iter70 - 	Loss1: -6.245023- 	Loss2: -12.190649- 	Loss_total: -18.435672
# Train Epoch 17:iter80 - 	Loss1: -6.236245- 	Loss2: -12.237921- 	Loss_total: -18.474166
# Train Epoch 17:iter90 - 	Loss1: -6.339375- 	Loss2: -12.182379- 	Loss_total: -18.521753
# Train Epoch 17:iter100 - 	Loss1: -6.282313- 	Loss2: -12.200787- 	Loss_total: -18.483099
# Train Epoch 17:iter110 - 	Loss1: -6.232203- 	Loss2: -12.179413- 	Loss_total: -18.411615
# Train Epoch 18:iter0 - 	Loss1: -6.341550- 	Loss2: -12.253826- 	Loss_total: -18.595376
# Train Epoch 18:iter10 - 	Loss1: -6.380009- 	Loss2: -12.205149- 	Loss_total: -18.585157
# Train Epoch 18:iter20 - 	Loss1: -6.309412- 	Loss2: -12.260298- 	Loss_total: -18.569710
# Train Epoch 18:iter30 - 	Loss1: -6.286110- 	Loss2: -12.226129- 	Loss_total: -18.512239
# Train Epoch 18:iter40 - 	Loss1: -6.270224- 	Loss2: -12.142398- 	Loss_total: -18.412621
# Train Epoch 18:iter50 - 	Loss1: -6.138880- 	Loss2: -12.194401- 	Loss_total: -18.333281
# Train Epoch 18:iter60 - 	Loss1: -6.338027- 	Loss2: -12.198614- 	Loss_total: -18.536641
# Train Epoch 18:iter70 - 	Loss1: -6.282657- 	Loss2: -12.170227- 	Loss_total: -18.452884
# Train Epoch 18:iter80 - 	Loss1: -6.255979- 	Loss2: -12.201077- 	Loss_total: -18.457055
# Train Epoch 18:iter90 - 	Loss1: -6.293137- 	Loss2: -12.253894- 	Loss_total: -18.547030
# Train Epoch 18:iter100 - 	Loss1: -6.301790- 	Loss2: -12.196545- 	Loss_total: -18.498334
# Train Epoch 18:iter110 - 	Loss1: -6.324405- 	Loss2: -12.211411- 	Loss_total: -18.535815
# Train Epoch 19:iter0 - 	Loss1: -6.238861- 	Loss2: -12.250704- 	Loss_total: -18.489564
# Train Epoch 19:iter10 - 	Loss1: -6.296810- 	Loss2: -12.262786- 	Loss_total: -18.559596
# Train Epoch 19:iter20 - 	Loss1: -6.366427- 	Loss2: -12.342122- 	Loss_total: -18.708549
# Train Epoch 19:iter30 - 	Loss1: -6.293683- 	Loss2: -12.291552- 	Loss_total: -18.585235
# Train Epoch 19:iter40 - 	Loss1: -6.313117- 	Loss2: -12.200641- 	Loss_total: -18.513758
# Train Epoch 19:iter50 - 	Loss1: -6.283590- 	Loss2: -12.232780- 	Loss_total: -18.516369
# Train Epoch 19:iter60 - 	Loss1: -6.204791- 	Loss2: -12.237836- 	Loss_total: -18.442627
# Train Epoch 19:iter70 - 	Loss1: -6.372014- 	Loss2: -12.302427- 	Loss_total: -18.674441
# Train Epoch 19:iter80 - 	Loss1: -6.319477- 	Loss2: -12.294371- 	Loss_total: -18.613848
# Train Epoch 19:iter90 - 	Loss1: -6.309402- 	Loss2: -12.265471- 	Loss_total: -18.574874
# Train Epoch 19:iter100 - 	Loss1: -6.312735- 	Loss2: -12.246490- 	Loss_total: -18.559226
# Train Epoch 19:iter110 - 	Loss1: -6.357791- 	Loss2: -12.272926- 	Loss_total: -18.630717

# %%
# モデル分類のクラスターの結果を確認する

def test(model, device, train_loader):
    model.eval()

    # 結果を格納するリスト
    out_targs = []
    ref_targs = []
    cnt = 0

    with torch.no_grad():
        for data, target in test_loader:
            cnt += 1
            data = data.to(device)
            target = target.to(device)
            outputs, outputs_overclustering = model(data)

            # 分類結果をリストに追加
            out_targs.append(outputs.argmax(dim=1).cpu())
            ref_targs.append(target.cpu())

    # リストをひとまとめに
    out_targs = torch.cat(out_targs)
    ref_targs = torch.cat(ref_targs)

    return out_targs.numpy(), ref_targs.numpy()


out_targs, ref_targs = test(model_trained, device, train_loader)

# %%
import numpy as np
import scipy.stats as stats

# 混同行列（的な）を作る
matrix = np.zeros((10, 10))

# 縦に数字の0から9を、横に判定されたクラスの頻度表を作成
for i in range(len(out_targs)):
    row = ref_targs[i]
    col = out_targs[i]
    matrix[row][col] += 1

np.set_printoptions(suppress=True)
print(matrix)
# Out:
# [[   0.    2.    1.    0.    1.    0.    0.    0.  974.    2.]
#  [   2.    7.    2. 1101.   18.    4.    0.    0.    0.    1.]
#  [   0. 1020.    7.    0.    2.    1.    0.    0.    1.    1.]
#  [   0.    2.    2.    0.    7.  995.    0.    4.    0.    0.]
#  [   1.    0.    0.    0.    0.    0.    0.    7.    0.  974.]
#  [   1.    1.    1.    0.   12.    8.  867.    0.    2.    0.]
#  [ 926.    1.    0.    0.    5.    0.    2.    0.   19.    5.]
#  [   0.    6.  904.    2.    0.    2.    0.  112.    0.    2.]
#  [   0.    2.    1.    0.  961.    1.    0.    5.    2.    2.]
#  [   0.    1.    6.    5.   12.   17.    0.  959.    2.    7.]]

# %%
# 全データ
total_num = matrix.sum().sum()
print(total_num)

# 各数字がきれいに各クラスに分かれている。
# 例えば数字の0はクラスの1番目に978個集まった。数字の9であれば、7番目に949個集まった。
# よって、最大のものを足していくと、正解の個数なので
correct_num_list = matrix.max(axis=0)
print(correct_num_list)
print(correct_num_list.sum())

print("正解率：", correct_num_list.sum()/total_num*100)
# Out:
# 10000.0
# [ 926. 1020.  904. 1101.  961.  995.  867.  959.  974.  974.]
# 9681.0
# 正解率： 96.81

# %% [markdown]
# 以上。
